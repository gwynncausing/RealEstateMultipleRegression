# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

import statsmodels.api as sm
from statsmodels.stats import diagnostic as diag
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Import label encoder 
from sklearn import preprocessing 

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

import pylab
import math

# %%
# importing dataset
data = pd.read_csv("Dataset.csv", encoding='cp1252')
data
# Out:
#                                                   Name  Car Spaces  Bedrooms  \
# 0    Bungalow House & Lot for sale in Lapu-Lapu Cit...         2.0       2.0
# 1      Ready for occupancy single detached Beach house         1.0       3.0
# 2    Two Storey House Villa with Pool - Camotes Isl...         5.0       3.0
# 3                 A Luxury 5-Bedroom Resort-Style Home         4.0       5.0
# 4          Townhouse for Sale in Banilad, Mandaue City         1.0       4.0
# ..                                                 ...         ...       ...
# 262            House and Lot For Sale at Cordova, Cebu         NaN       3.0
# 263             A 5-bedroom Home for Sale in Maryville         NaN       3.0
# 264  3-BR House and Lot for Sale at Pacific Grand V...         NaN       3.0
# 265             House and Lot For Sale at Liloan, Cebu         2.0       3.0
# 266       House and Lot for Sale in Modena Subdivision         NaN       4.0
#
#      Bathrooms  Floor area (m2)  Land Size(m2)  Waterfront        Location  \
# 0          3.0            150.0          173.0         1.0       Lapu-Lapu
# 1          2.0             80.0          291.0         1.0           Argao
# 2          2.0            385.4         1500.0         1.0  Camotes Island
# 3          5.0            360.0          462.0         0.0       Lapu-Lapu
# 4          3.0            103.0           60.0         0.0         Mandaue
# ..         ...              ...            ...         ...             ...
# 262        2.0             63.0           62.0         0.0         Cordova
# 263        5.0            450.0          438.0         0.0            Cebu
# 264        3.0            156.0          144.0         0.0       Lapu-Lapu
# 265        3.0            150.0          170.0         0.0          Liloan
# 266        2.0             84.0           90.0         0.0       Lapu-Lapu
#
#              Price
# 0     3,800,000.00
# 1     7,078,000.00
# 2    11,900,000.00
# 3    52,000,000.00
# 4    10,500,000.00
# ..             ...
# 262      2,705,711
# 263     30,000,000
# 264     15,000,000
# 265      8,000,000
# 266      5,600,000
#
# [267 rows x 9 columns]

# %%
# renaming columns
data.columns = ['name', 'carspaces', 'bedrooms', 'bathrooms', 'floorarea', 'landsize', 'waterfront', 'location', 'price']

# %%
data[data['name'].duplicated() == True]
# Out:
#                                                   name  carspaces  bedrooms  \
# 86   House for sale at Tres de Abril St., Punta Pri...        4.0       5.0
# 107  House and Lot for Sale in Maryville Subdivisio...        1.0       4.0
# 119  Briella (RFO) 2 storey single detached with ba...        2.0       5.0
# 139     4Br House and Lot For Sale in Banawa Cebu City        2.0       4.0
# 151  Furnished 3 Bedroom House for Sale near Cebu I...        1.0       3.0
# 156  2 BR-RFO TOWNHOUSE WITH 2 T&B AND 1 CARPORT/lo...        1.0       2.0
# 189  Two Storey House Villa with Pool - Camotes Isl...        NaN       3.0
# 204       10-Bedroom House and Lot for Sale, Cebu City        NaN      10.0
# 214        1 Bedroom Townhouse in Agus, Lapu-Lapu City        NaN       1.0
# 221  Beautiful exclusive pocket subdivision in Pobl...        1.0       3.0
# 229  Brand New House and Lot 4 bedrooms in South hi...        2.0       4.0
# 230         Beach House in Daanlungsod, Medellin, Cebu        NaN       3.0
# 241     Affordable House and Lot for Sale in Cebu City        2.0       3.0
#
#      bathrooms  floorarea  landsize  waterfront     location       price
# 86         5.0      328.0     200.5         0.0         Cebu  22,850,000
# 107        4.0      185.0     250.0         NaN         Cebu  15,000,000
# 119        4.0      210.0     180.0         NaN  Minglanilla   9,133,966
# 139        4.0      114.0      75.0         NaN         Cebu   8,652,000
# 151        3.0      200.0     140.0         NaN         Cebu  18,000,000
# 156        2.0       65.0      40.0         NaN  Minglanilla   3,500,000
# 189        2.0      385.4    1500.0         1.0      Camotes  11,900,000
# 204       10.0      527.0     267.0         0.0         Cebu  20,000,000
# 214        1.0       54.0      35.0         0.0    Lapu-Lapu   1,500,000
# 221        2.0       61.0      59.0         0.0         Cebu   4,200,000
# 229        4.0      390.0     150.0         0.0         Cebu  19,500,000
# 230        2.0        NaN     247.0         NaN     Medellin   8,200,000
# 241        2.0      140.0     170.0         0.0         Cebu  10,000,000

# %%
data.drop_duplicates(subset = ["name"], keep = 'first', inplace = True) 
data[data['name'].duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [name, carspaces, bedrooms, bathrooms, floorarea, landsize, waterfront, location, price]
# Index: []

# %%
data
# Out:
#                                                   name  carspaces  bedrooms  \
# 0    Bungalow House & Lot for sale in Lapu-Lapu Cit...        2.0       2.0
# 1      Ready for occupancy single detached Beach house        1.0       3.0
# 2    Two Storey House Villa with Pool - Camotes Isl...        5.0       3.0
# 3                 A Luxury 5-Bedroom Resort-Style Home        4.0       5.0
# 4          Townhouse for Sale in Banilad, Mandaue City        1.0       4.0
# ..                                                 ...        ...       ...
# 262            House and Lot For Sale at Cordova, Cebu        NaN       3.0
# 263             A 5-bedroom Home for Sale in Maryville        NaN       3.0
# 264  3-BR House and Lot for Sale at Pacific Grand V...        NaN       3.0
# 265             House and Lot For Sale at Liloan, Cebu        2.0       3.0
# 266       House and Lot for Sale in Modena Subdivision        NaN       4.0
#
#      bathrooms  floorarea  landsize  waterfront        location          price
# 0          3.0      150.0     173.0         1.0       Lapu-Lapu   3,800,000.00
# 1          2.0       80.0     291.0         1.0           Argao   7,078,000.00
# 2          2.0      385.4    1500.0         1.0  Camotes Island  11,900,000.00
# 3          5.0      360.0     462.0         0.0       Lapu-Lapu  52,000,000.00
# 4          3.0      103.0      60.0         0.0         Mandaue  10,500,000.00
# ..         ...        ...       ...         ...             ...            ...
# 262        2.0       63.0      62.0         0.0         Cordova      2,705,711
# 263        5.0      450.0     438.0         0.0            Cebu     30,000,000
# 264        3.0      156.0     144.0         0.0       Lapu-Lapu     15,000,000
# 265        3.0      150.0     170.0         0.0          Liloan      8,000,000
# 266        2.0       84.0      90.0         0.0       Lapu-Lapu      5,600,000
#
# [254 rows x 9 columns]

# %%
# check for null values
display(data.isnull().any())
# Out:
# name          False
# carspaces      True
# bedrooms       True
# bathrooms      True
# floorarea      True
# landsize       True
# waterfront     True
# location      False
# price          True
# dtype: bool

# %%
# identify the mean of carspaces column to fill in null columns
data['carspaces'].mean()
# Out:
# 2.0122699386503067

# %%
# # filling null values
data[['carspaces']] = data[['carspaces']].fillna(data['carspaces'].mean())
display(data.isnull().any())
# Out:
# name          False
# carspaces     False
# bedrooms       True
# bathrooms      True
# floorarea      True
# landsize       True
# waterfront     True
# location      False
# price          True
# dtype: bool

# %%
data[['bedrooms']] = data[['bedrooms']].fillna(data['bedrooms'].mean())
data[['bathrooms']] = data[['bathrooms']].fillna(data['bathrooms'].mean())
data[['floorarea']] = data[['floorarea']].fillna(data['floorarea'].mean())
data[['landsize']] = data[['landsize']].fillna(data['landsize'].mean())
data[['waterfront']] = data[['waterfront']].fillna('0')
display(data.isnull().any())
# Out:
# name          False
# carspaces     False
# bedrooms      False
# bathrooms     False
# floorarea     False
# landsize      False
# waterfront    False
# location      False
# price          True
# dtype: bool

# %%
display(data.isnull().any())
# Out:
# name          False
# carspaces     False
# bedrooms      False
# bathrooms     False
# floorarea     False
# landsize      False
# waterfront    False
# location      False
# price          True
# dtype: bool

# %%
# now, the price has the only column that contains null values
# we will be remove those rows with null prices since we are predicting the prices for house sales
data.dropna(axis = 0, how = 'any', inplace = True)
data
# Out:
#                                                   name  carspaces  bedrooms  \
# 0    Bungalow House & Lot for sale in Lapu-Lapu Cit...    2.00000       2.0
# 1      Ready for occupancy single detached Beach house    1.00000       3.0
# 2    Two Storey House Villa with Pool - Camotes Isl...    5.00000       3.0
# 3                 A Luxury 5-Bedroom Resort-Style Home    4.00000       5.0
# 4          Townhouse for Sale in Banilad, Mandaue City    1.00000       4.0
# ..                                                 ...        ...       ...
# 262            House and Lot For Sale at Cordova, Cebu    2.01227       3.0
# 263             A 5-bedroom Home for Sale in Maryville    2.01227       3.0
# 264  3-BR House and Lot for Sale at Pacific Grand V...    2.01227       3.0
# 265             House and Lot For Sale at Liloan, Cebu    2.00000       3.0
# 266       House and Lot for Sale in Modena Subdivision    2.01227       4.0
#
#      bathrooms  floorarea  landsize waterfront        location          price
# 0          3.0      150.0     173.0          1       Lapu-Lapu   3,800,000.00
# 1          2.0       80.0     291.0          1           Argao   7,078,000.00
# 2          2.0      385.4    1500.0          1  Camotes Island  11,900,000.00
# 3          5.0      360.0     462.0          0       Lapu-Lapu  52,000,000.00
# 4          3.0      103.0      60.0          0         Mandaue  10,500,000.00
# ..         ...        ...       ...        ...             ...            ...
# 262        2.0       63.0      62.0          0         Cordova      2,705,711
# 263        5.0      450.0     438.0          0            Cebu     30,000,000
# 264        3.0      156.0     144.0          0       Lapu-Lapu     15,000,000
# 265        3.0      150.0     170.0          0          Liloan      8,000,000
# 266        2.0       84.0      90.0          0       Lapu-Lapu      5,600,000
#
# [248 rows x 9 columns]

# %%
data.drop('name', axis = 1, inplace = True)
data
# Out:
#      carspaces  bedrooms  bathrooms  floorarea  landsize waterfront  \
# 0      2.00000       2.0        3.0      150.0     173.0          1
# 1      1.00000       3.0        2.0       80.0     291.0          1
# 2      5.00000       3.0        2.0      385.4    1500.0          1
# 3      4.00000       5.0        5.0      360.0     462.0          0
# 4      1.00000       4.0        3.0      103.0      60.0          0
# ..         ...       ...        ...        ...       ...        ...
# 262    2.01227       3.0        2.0       63.0      62.0          0
# 263    2.01227       3.0        5.0      450.0     438.0          0
# 264    2.01227       3.0        3.0      156.0     144.0          0
# 265    2.00000       3.0        3.0      150.0     170.0          0
# 266    2.01227       4.0        2.0       84.0      90.0          0
#
#            location          price
# 0         Lapu-Lapu   3,800,000.00
# 1             Argao   7,078,000.00
# 2    Camotes Island  11,900,000.00
# 3         Lapu-Lapu  52,000,000.00
# 4           Mandaue  10,500,000.00
# ..              ...            ...
# 262         Cordova      2,705,711
# 263            Cebu     30,000,000
# 264       Lapu-Lapu     15,000,000
# 265          Liloan      8,000,000
# 266       Lapu-Lapu      5,600,000
#
# [248 rows x 8 columns]

# %%
# identify if the location values are all provinces
location_list = data.location.unique()
location_list
# Out:
# array(['Lapu-Lapu', 'Argao', 'Camotes Island', 'Mandaue', 'Cebu',
#        'Consolacion', 'Bogo', 'Oslob', 'Talisay', 'Liloan', 'Medellin',
#        'Compostela', 'Minglanilla', 'Alcoy', 'Lapu-lapu', 'Cordova',
#        'Toledo', 'Talamban', 'Borbon', 'Bantayan', 'Santander', 'Badian',
#        'Banilad', 'Guadalupe', 'Naga', 'Lahug', 'Danao', 'Carcar',
#        'Catmon', 'Guadalupe, Cebu', 'Carmen'], dtype=object)

# %%
data.loc[data['location'].str.contains('Guadalupe'), 'location'] = 'Cebu'
data.loc[data['location'].str.contains('Cordova'), 'location'] = 'Lapu-Lapu'
data.loc[data['location'].str.contains('Camotes'), 'location'] = 'Camotes Island'
data.loc[data['location'].str.contains('Bantayan'), 'location'] = 'Bantayan Island'

# %%
# sorting the list
location_list = data.location.unique()
location_list.sort()
location_list
# Out:
# array(['Alcoy', 'Argao', 'Badian', 'Banilad', 'Bantayan Island', 'Bogo',
#        'Borbon', 'Camotes Island', 'Carcar', 'Carmen', 'Catmon', 'Cebu',
#        'Compostela', 'Consolacion', 'Danao', 'Lahug', 'Lapu-Lapu',
#        'Lapu-lapu', 'Liloan', 'Mandaue', 'Medellin', 'Minglanilla',
#        'Naga', 'Oslob', 'Santander', 'Talamban', 'Talisay', 'Toledo'],
#       dtype=object)

# %%
# identify the number of provinces in the dataset composed of 28 provinces
len(location_list)
# Out:
# 28

# %%
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()

# %%
# Encode labels in column 'location'. 
# This converts the categorical into numerical
data['location']= label_encoder.fit_transform(data['location']) 
data
# Out:
#      carspaces  bedrooms  bathrooms  floorarea  landsize waterfront  location  \
# 0      2.00000       2.0        3.0      150.0     173.0          1        16
# 1      1.00000       3.0        2.0       80.0     291.0          1         1
# 2      5.00000       3.0        2.0      385.4    1500.0          1         7
# 3      4.00000       5.0        5.0      360.0     462.0          0        16
# 4      1.00000       4.0        3.0      103.0      60.0          0        19
# ..         ...       ...        ...        ...       ...        ...       ...
# 262    2.01227       3.0        2.0       63.0      62.0          0        16
# 263    2.01227       3.0        5.0      450.0     438.0          0        11
# 264    2.01227       3.0        3.0      156.0     144.0          0        16
# 265    2.00000       3.0        3.0      150.0     170.0          0        18
# 266    2.01227       4.0        2.0       84.0      90.0          0        16
#
#              price
# 0     3,800,000.00
# 1     7,078,000.00
# 2    11,900,000.00
# 3    52,000,000.00
# 4    10,500,000.00
# ..             ...
# 262      2,705,711
# 263     30,000,000
# 264     15,000,000
# 265      8,000,000
# 266      5,600,000
#
# [248 rows x 8 columns]

# %%
# TODO: check for duplicates
